# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error


from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import time
import datetime
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold
from sklearn.metrics import mean_absolute_error
import gc
import seaborn as sns
import warnings

from scipy.signal import hilbert
from scipy.signal import hann
from scipy.signal import convolve
from scipy import stats
from sklearn.kernel_ridge import KernelRidge
from tsfresh.feature_extraction import feature_calculators
import copy

# %%
train = pd.read_csv("../input/train.csv", dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})

# %%
# Display time_to_failure with more units of precision
pd.options.display.precision = 15

# Create a training file with simple derived features
rows = 150_000
segments = int(np.floor(train.shape[0] / rows))

X_tr = pd.DataFrame(index=range(segments), dtype=np.float64)

y_train = pd.DataFrame(index=range(segments), dtype=np.float64, columns=['time_to_failure'])

total_mean = train['acoustic_data'].mean()
total_std = train['acoustic_data'].std()
total_max = train['acoustic_data'].max()
total_min = train['acoustic_data'].min()
total_sum = train['acoustic_data'].sum()
total_abs_sum = np.abs(train['acoustic_data']).sum()

for segment in tqdm_notebook(range(segments)):
    seg = train.iloc[segment*rows:segment*rows+rows]
    x = pd.Series(seg['acoustic_data'].values)
    y = seg['time_to_failure'].values[-1]
    y_train.loc[segment, 'time_to_failure'] = y
    
    zc = np.fft.fft(x)
    realFFT = np.real(zc)
    imagFFT = np.imag(zc)
    X_tr.loc[segment, 'Rmean'] = realFFT.mean()
    X_tr.loc[segment, 'Rstd'] = realFFT.std()
    X_tr.loc[segment, 'Rmax'] = realFFT.max()
    X_tr.loc[segment, 'Rmin'] = realFFT.min()
    X_tr.loc[segment, 'Imean'] = imagFFT.mean()
    X_tr.loc[segment, 'Istd'] = imagFFT.std()
    X_tr.loc[segment, 'Imax'] = imagFFT.max()
    X_tr.loc[segment, 'Imin'] = imagFFT.min()
    
    
    X_tr.loc[segment, 'mean'] = x.mean()
    X_tr.loc[segment, 'std'] = x.std()
    X_tr.loc[segment, 'max'] = x.max()
    X_tr.loc[segment, 'min'] = x.min()
    X_tr.loc[segment, 'kurt'] = x.kurtosis()
    X_tr.loc[segment, 'num_peaks_10'] = feature_calculators.number_peaks(x, 10)
    X_tr.loc[segment, 'autocorrelation_5'] = feature_calculators.autocorrelation(x, 5)
    
    for windows in [10, 100, 1000]:
        x_roll_std = x.rolling(windows).std().dropna().values
        x_roll_mean = x.rolling(windows).mean().dropna().values
        
        X_tr.loc[segment, 'max_roll_mean_' + str(windows)] = x_roll_mean.max()
        X_tr.loc[segment, 'min_roll_mean_' + str(windows)] = x_roll_mean.min()
        X_tr.loc[segment, 'q01_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.01) #Als je niet weet wat dit doet vraag het aan Pepijn
        X_tr.loc[segment, 'q05_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.05)
        X_tr.loc[segment, 'q95_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.95)
        
        X_tr.loc[segment, 'q01_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.01)
        X_tr.loc[segment, 'q05_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.05)
        X_tr.loc[segment, 'q95_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.95)
        X_tr.loc[segment, 'min_roll_std_' + str(windows)] = x_roll_std.min()
        X_tr.loc[segment, 'ave_roll_mean' + str(windows)] = x_roll_mean.mean()
# Out:
# HBox(children=(IntProgress(value=0, max=4194), HTML(value='')))

# %%
means_dict = {}
for col in X_tr.columns:
    if X_tr[col].isnull().any():
        print(col)
        mean_value = X_tr.loc[X_tr[col] != -np.inf, col].mean()
        X_tr.loc[X_tr[col] == -np.inf, col] = mean_value
        X_tr[col] = X_tr[col].fillna(mean_value)
        means_dict[col] = mean_value

scaler = StandardScaler()
scaler.fit(X_tr)
X_train_scaled = pd.DataFrame(scaler.transform(X_tr), columns=X_tr.columns)

# %%
submission = pd.read_csv('../input/sample_submission.csv', index_col='seg_id')
X_test = pd.DataFrame(columns=X_tr.columns, dtype=np.float64, index=submission.index)

for i, seg_id in enumerate(tqdm_notebook(X_test.index)):
    seg = pd.read_csv('../input/test/' + seg_id + '.csv')
    
    x = pd.Series(seg['acoustic_data'].values)
    zc = np.fft.fft(x)
    realFFT = np.real(zc)
    imagFFT = np.imag(zc)
    
    X_test.loc[seg_id, 'Rmean'] = realFFT.mean()
    X_test.loc[seg_id, 'Rstd'] = realFFT.std()
    X_test.loc[seg_id, 'Rmax'] = realFFT.max()
    X_test.loc[seg_id, 'Rmin'] = realFFT.min()
    X_test.loc[seg_id, 'Imean'] = imagFFT.mean()
    X_test.loc[seg_id, 'Istd'] = imagFFT.std()
    X_test.loc[seg_id, 'Imax'] = imagFFT.max()
    X_test.loc[seg_id, 'Imin'] = imagFFT.min()
    
    X_test.loc[seg_id, 'mean'] = x.mean()
    X_test.loc[seg_id, 'std'] = x.std()
    X_test.loc[seg_id, 'max'] = x.max()
    X_test.loc[seg_id, 'min'] = x.min()  

    X_test.loc[seg_id, 'kurt'] = x.kurtosis()

    X_test.loc[seg_id, 'num_peaks_10'] = feature_calculators.number_peaks(x, 10)
    X_test.loc[seg_id, 'autocorrelation_5'] = feature_calculators.autocorrelation(x, 5)
    
    for windows in [10, 100, 1000]:
        x_roll_std = x.rolling(windows).std().dropna().values
        x_roll_mean = x.rolling(windows).mean().dropna().values
                
        X_test.loc[seg_id, 'max_roll_mean_' + str(windows)] = x_roll_mean.max()
        X_test.loc[seg_id, 'min_roll_mean_' + str(windows)] = x_roll_mean.min()
        X_test.loc[seg_id, 'q01_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.01)
        X_test.loc[seg_id, 'q05_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.05)
        X_test.loc[seg_id, 'q95_roll_mean_' + str(windows)] = np.quantile(x_roll_mean, 0.95)
        
        X_test.loc[seg_id, 'q01_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.01)
        X_test.loc[seg_id, 'q05_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.05)
        X_test.loc[seg_id, 'q95_roll_std_' + str(windows)] = np.quantile(x_roll_std, 0.95)
        X_test.loc[seg_id, 'min_roll_std_' + str(windows)] = x_roll_std.min()
        X_test.loc[seg_id, 'ave_roll_mean' + str(windows)] = x_roll_mean.mean()
        
for col in X_test.columns:
    if X_test[col].isnull().any():
        X_test.loc[X_test[col] == -np.inf, col] = means_dict[col]
        X_test[col] = X_test[col].fillna(means_dict[col])
        
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
# Out:
# HBox(children=(IntProgress(value=0, max=2624), HTML(value='')))

# %%
from gplearn.genetic import SymbolicRegressor
from gplearn.functions import make_function

def tanh(x):
    return np.tanh(x);
def sinh(x):
    return np.sinh(x);

gp_tanh = make_function(tanh,"tanh",1)
gp_sinh = make_function(sinh,"sinh",1)
f_set = ['add', 'sub', 'mul', 'div', 'inv', 'abs', 'neg', 'max', 'min','sqrt','log', gp_tanh, gp_sinh]

# %%
est_gp = SymbolicRegressor(population_size=2000,
                               tournament_size=50,
                               generations=40, stopping_criteria=0.0,
                               p_crossover=0.7, p_subtree_mutation=0.05, p_hoist_mutation=0.05, p_point_mutation=0.05,
                               max_samples=1.0, verbose=1,
                               function_set = (gp_tanh,'sqrt', 'add', 'sub', 'mul', 'div','log','sin','cos','neg','max','min','abs'),
                               metric = 'mean absolute error', warm_start=True,
                               n_jobs = -1, parsimony_coefficient=0.00001, random_state=11)

# %%
predictions = np.zeros(len(X_test_scaled))

n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=False, random_state=42)

fold_importance_df = pd.DataFrame()
fold_importance_df["Feature"] = X_train_scaled.columns

# %%
GENS = 75
MAE_THRESH = 2.5
MAX_NO_IMPROVE = 50

maes = []
gens = []

for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train_scaled, y_train.values.flatten())):
    X_tr, X_val = X_train_scaled.iloc[trn_idx], X_train_scaled.iloc[val_idx]
    y_tr, y_val = y_train['time_to_failure'].values[trn_idx].ravel(), y_train['time_to_failure'].values[val_idx].ravel()
    best = 1e10
    count = 1
    imp_count = 0
    best_mdl = None
    best_iter = 0
    gp = SymbolicRegressor(population_size=2000,
                               tournament_size=30,
                               generations=count, stopping_criteria=0.0,
                               p_crossover=0.7, p_subtree_mutation=0.1, p_hoist_mutation=0.1, p_point_mutation=0.1,
                               max_samples=1.0, verbose=1,
                               function_set = (gp_tanh,'sqrt', 'add', 'sub', 'mul', 'div','log','sin','cos','neg','max','min','abs'),
                               metric = 'mean absolute error', warm_start=True,
                               n_jobs = -1, parsimony_coefficient=0.00001, random_state=11)

    for run in range(GENS):
        mdl = gp.fit(X_tr, y_tr)
        pred = gp.predict(X_val)
        mae = np.sqrt(mean_absolute_error(y_val, pred))

        if mae < best and imp_count < MAX_NO_IMPROVE:
            best = mae
            count += 1
            gp.set_params(generations=count, warm_start=True)
            imp_count = 0
            best_iter = run
            if mae < MAE_THRESH:
                best_mdl = copy.deepcopy(mdl)
        elif imp_count < MAX_NO_IMPROVE:
            count += 1
            gp.set_params(generations=count, warm_start=True)
            imp_count += 1
        else:
            break

        print('GP MAE: %.4f, Run: %d, Best Run: %d, Fold: %d' % (mae, run, best_iter, fold_))

    maes.append(best)
    gens.append(run)
      
    print('Finish - GP MAE: %.4f, Run: %d, Best Run: %d' % (mae, run, best_iter))
          
    preds = best_mdl.predict(X_test_scaled)
    print(preds[0:12])
    predictions += preds / folds.n_splits

try:
    print(maes)
    print(np.mean(maes))
    print(gens)
except:
    print('oops')
submission.time_to_failure = predictions
submission.to_csv('submission_gplearn_AF0_1.csv')
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.16          7.09622       14          3.37427              N/A      0.00s
# GP MAE: 1.8476, Run: 0, Best Run: 0, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    1    14.45          5.34254       23          3.24902              N/A      0.00s
# GP MAE: 1.8212, Run: 1, Best Run: 1, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    2    16.60          4.54024       39           2.9414              N/A      0.00s
# GP MAE: 1.6953, Run: 2, Best Run: 2, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    3    18.21          4.00817       38          2.88713              N/A      0.00s
# GP MAE: 1.7190, Run: 3, Best Run: 2, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    4    28.05          3.68823       36          2.38482              N/A      0.00s
# GP MAE: 1.5174, Run: 4, Best Run: 4, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    5    33.38          3.45334       42          2.36041              N/A      0.00s
# GP MAE: 1.5229, Run: 5, Best Run: 4, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    6    37.30          3.20188       46          2.22514              N/A      0.00s
# GP MAE: 1.4868, Run: 6, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    7    43.59          2.92476       48          2.17274              N/A      0.00s
# GP MAE: 1.5297, Run: 7, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    8    49.92          2.89983       50          2.16612              N/A      0.00s
# GP MAE: 1.5056, Run: 8, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    9    56.45          2.75037       38          2.12483              N/A      0.00s
# GP MAE: 1.5277, Run: 9, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   10    62.64          2.70873       56          2.09419              N/A      0.00s
# GP MAE: 1.4914, Run: 10, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   11    71.87          2.59618       56          2.09419              N/A      0.00s
# GP MAE: 1.4914, Run: 11, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   12    69.66           2.6668       54          2.08995              N/A      0.00s
# GP MAE: 1.4928, Run: 12, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   13    67.55          2.52298       59          2.07531              N/A      0.00s
# GP MAE: 1.4941, Run: 13, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   14    65.16           2.5162       60          2.07056              N/A      0.00s
# GP MAE: 1.4936, Run: 14, Best Run: 6, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   15    71.11            2.439       91          2.06521              N/A      0.00s
# GP MAE: 1.4738, Run: 15, Best Run: 15, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   16    73.97          2.44866       76          2.06073              N/A      0.00s
# GP MAE: 1.4930, Run: 16, Best Run: 15, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   17    82.91          2.43451      113          2.06055              N/A      0.00s
# GP MAE: 1.4839, Run: 17, Best Run: 15, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   18   101.06          2.32183      104          2.05707              N/A      0.00s
# GP MAE: 1.4901, Run: 18, Best Run: 15, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   19   100.19          2.38413       92          2.05119              N/A      0.00s
# GP MAE: 1.4801, Run: 19, Best Run: 15, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   20   108.11          2.34863      127          2.05003              N/A      0.00s
# GP MAE: 1.4735, Run: 20, Best Run: 20, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   21   115.22          2.28956      109          2.04831              N/A      0.00s
# GP MAE: 1.4722, Run: 21, Best Run: 21, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   22   118.05          2.39827      191          2.04262              N/A      0.00s
# GP MAE: 1.4728, Run: 22, Best Run: 21, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   23   128.44          2.35933      189          2.04249              N/A      0.00s
# GP MAE: 1.4730, Run: 23, Best Run: 21, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   24   130.87          2.31271      192          2.04115              N/A      0.00s
# GP MAE: 1.4723, Run: 24, Best Run: 21, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   25   164.77          2.33954      362          2.04055              N/A      0.00s
# GP MAE: 1.4733, Run: 25, Best Run: 21, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   26   183.55          2.23387      191          2.03946              N/A      0.00s
# GP MAE: 1.4685, Run: 26, Best Run: 26, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   27   180.62          2.25572      123          2.03647              N/A      0.00s
# GP MAE: 1.4678, Run: 27, Best Run: 27, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   28   181.75          2.20792      187          2.03482              N/A      0.00s
# GP MAE: 1.4668, Run: 28, Best Run: 28, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   29   176.01          2.28536      124          2.03413              N/A      0.00s
# GP MAE: 1.4704, Run: 29, Best Run: 28, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   30   164.67          2.25095      191          2.03243              N/A      0.00s
# GP MAE: 1.4650, Run: 30, Best Run: 30, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   31   150.68          2.26714      250          2.03231              N/A      0.00s
# GP MAE: 1.4675, Run: 31, Best Run: 30, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   32   152.53          2.27793      292          2.03106              N/A      0.00s
# GP MAE: 1.4662, Run: 32, Best Run: 30, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   33   168.95          2.23984      206          2.03028              N/A      0.00s
# GP MAE: 1.4635, Run: 33, Best Run: 33, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   34   166.58          2.28569      193          2.02828              N/A      0.00s
# GP MAE: 1.4633, Run: 34, Best Run: 34, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   35   162.09          2.26814      114           2.0254              N/A      0.00s
# GP MAE: 1.4707, Run: 35, Best Run: 34, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   36   159.97          2.27789      142          2.02145              N/A      0.00s
# GP MAE: 1.4577, Run: 36, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   37   160.21          2.21432      142          2.02145              N/A      0.00s
# GP MAE: 1.4577, Run: 37, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   38   160.55          2.26807      333          2.01923              N/A      0.00s
# GP MAE: 1.4683, Run: 38, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   39   171.22          2.28222      317          2.01748              N/A      0.00s
# GP MAE: 1.4674, Run: 39, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   40   196.59          2.37177      258          2.01556              N/A      0.00s
# GP MAE: 1.4691, Run: 40, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   41   254.76          2.21434      328          2.01314              N/A      0.00s
# GP MAE: 1.4658, Run: 41, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   42   251.08          2.18255      325          2.01162              N/A      0.00s
# GP MAE: 1.4626, Run: 42, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   43   254.94          2.22383      312          2.01119              N/A      0.00s
# GP MAE: 1.4594, Run: 43, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   44   277.44          2.21665      292          2.00923              N/A      0.00s
# GP MAE: 1.4587, Run: 44, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   45   279.35           2.2345      291          2.00736              N/A      0.00s
# GP MAE: 1.4587, Run: 45, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   46   286.22          2.17019      279          2.00624              N/A      0.00s
# GP MAE: 1.4619, Run: 46, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   47   286.48          2.15526      273          2.00606              N/A      0.00s
# GP MAE: 1.4586, Run: 47, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   48   288.72          2.20005      306          2.00451              N/A      0.00s
# GP MAE: 1.4590, Run: 48, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   49   284.90          2.15304      310          2.00378              N/A      0.00s
# GP MAE: 1.4589, Run: 49, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   50   286.03          2.15823      312          2.00343              N/A      0.00s
# GP MAE: 1.4594, Run: 50, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   51   297.59          2.14103      312          2.00343              N/A      0.00s
# GP MAE: 1.4594, Run: 51, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   52   301.57           2.2089      300          2.00309              N/A      0.00s
# GP MAE: 1.4593, Run: 52, Best Run: 36, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   53   299.44          2.18384      509          2.00196              N/A      0.00s
# GP MAE: 1.4482, Run: 53, Best Run: 53, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   54   292.32          2.16214      507          2.00249              N/A      0.00s
# GP MAE: 1.4480, Run: 54, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   55   289.49           2.1738      302          2.00234              N/A      0.00s
# GP MAE: 1.4550, Run: 55, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   56   280.87          2.19783      299          2.00202              N/A      0.00s
# GP MAE: 1.4554, Run: 56, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   57   281.84          2.14885      260          2.00199              N/A      0.00s
# GP MAE: 1.4553, Run: 57, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   58   279.56          2.14767      263          2.00135              N/A      0.00s
# GP MAE: 1.4554, Run: 58, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   59   285.03          2.27274      293          2.00104              N/A      0.00s
# GP MAE: 1.4486, Run: 59, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   60   284.22          2.19163      295          2.00086              N/A      0.00s
# GP MAE: 1.4483, Run: 60, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   61   278.44          2.15891      278          1.99949              N/A      0.00s
# GP MAE: 1.4499, Run: 61, Best Run: 54, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   62   276.86          2.22324      299          1.99947              N/A      0.00s
# GP MAE: 1.4474, Run: 62, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   63   285.63          2.20759      271           1.9989              N/A      0.00s
# GP MAE: 1.4482, Run: 63, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   64   284.22          2.16043      314          1.99878              N/A      0.00s
# GP MAE: 1.4511, Run: 64, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   65   284.44          2.22875      291          1.99848              N/A      0.00s
# GP MAE: 1.4491, Run: 65, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   66   281.89          2.21494      315          1.99831              N/A      0.00s
# GP MAE: 1.4510, Run: 66, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   67   281.11          2.20297      453          1.99816              N/A      0.00s
# GP MAE: 1.4530, Run: 67, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   68   292.33          2.17047      318          1.99785              N/A      0.00s
# GP MAE: 1.4513, Run: 68, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   69   290.97          2.14206      275          1.99784              N/A      0.00s
# GP MAE: 1.4526, Run: 69, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   70   291.12          2.15573      314          1.99764              N/A      0.00s
# GP MAE: 1.4514, Run: 70, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   71   289.90          2.18702      294          1.99708              N/A      0.00s
# GP MAE: 1.4528, Run: 71, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   72   286.42          2.15153      293          1.99708              N/A      0.00s
# GP MAE: 1.4528, Run: 72, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   73   286.43          2.21386      298          1.99698              N/A      0.00s
# GP MAE: 1.4538, Run: 73, Best Run: 62, Fold: 0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   74   284.80          2.21489      310          1.99685              N/A      0.00s
# GP MAE: 1.4549, Run: 74, Best Run: 62, Fold: 0
# Finish - GP MAE: 1.4549, Run: 74, Best Run: 62
# [3.18482265 5.1917383  3.15117645 6.71547589 6.66423925 2.27195936
#  7.15462384 4.47694074 4.46523707 2.06997469 2.55434307 5.04564257]
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.16           7.3851       14           3.4247              N/A      0.00s
# GP MAE: 1.7922, Run: 0, Best Run: 0, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    1    14.43          5.59609       23          3.29414              N/A      0.00s
# GP MAE: 1.7710, Run: 1, Best Run: 1, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    2    16.86          4.87437       39          2.90771              N/A      0.00s
# GP MAE: 1.7346, Run: 2, Best Run: 2, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    3    17.75          4.13311       38           2.8857              N/A      0.00s
# GP MAE: 1.7206, Run: 3, Best Run: 3, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    4    26.80          3.74502       30          2.67019              N/A      0.00s
# GP MAE: 1.5871, Run: 4, Best Run: 4, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    5    36.67          3.50504       40           2.4562              N/A      0.00s
# GP MAE: 1.5707, Run: 5, Best Run: 5, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    6    36.51          3.45813       60          2.34228              N/A      0.00s
# GP MAE: 1.5517, Run: 6, Best Run: 6, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    7    43.36          3.09094       61          2.26089              N/A      0.00s
# GP MAE: 1.5944, Run: 7, Best Run: 6, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    8    57.02          2.94601       93          2.19268              N/A      0.00s
# GP MAE: 1.5610, Run: 8, Best Run: 6, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    9    73.28           2.6645      141          2.17923              N/A      0.00s
# GP MAE: 1.5481, Run: 9, Best Run: 9, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   10    90.31          2.56363      164          2.13137              N/A      0.00s
# GP MAE: 1.5096, Run: 10, Best Run: 10, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   11   106.65          2.56425      119          2.11746              N/A      0.00s
# GP MAE: 1.5126, Run: 11, Best Run: 10, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   12   133.00          2.50241      109          2.10868              N/A      0.00s
# GP MAE: 1.5251, Run: 12, Best Run: 10, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   13   147.27           2.3725      298           2.1022              N/A      0.00s
# GP MAE: 1.4940, Run: 13, Best Run: 13, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   14   149.94          2.35714      165          2.08705              N/A      0.00s
# GP MAE: 1.5006, Run: 14, Best Run: 13, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   15   170.98          2.39194      283          2.07001              N/A      0.00s
# GP MAE: 1.4910, Run: 15, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   16   193.12          2.30693      345          2.05325              N/A      0.00s
# GP MAE: 1.4999, Run: 16, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   17   231.78          2.34198      350          2.04768              N/A      0.00s
# GP MAE: 1.5043, Run: 17, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   18   301.58          2.29018      347          2.04218              N/A      0.00s
# GP MAE: 1.5251, Run: 18, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   19   338.74          2.26222      607          2.03899              N/A      0.00s
# GP MAE: 1.5183, Run: 19, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   20   347.18          2.25816      403          2.03589              N/A      0.00s
# GP MAE: 1.5152, Run: 20, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   21   327.88          2.24144      304          2.03344              N/A      0.00s
# GP MAE: 1.5194, Run: 21, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   22   331.37          2.20161      434          2.03147              N/A      0.00s
# GP MAE: 1.5234, Run: 22, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   23   302.43          2.18824      269          2.02692              N/A      0.00s
# GP MAE: 1.5236, Run: 23, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   24   287.43          2.21671      296          2.02189              N/A      0.00s
# GP MAE: 1.5212, Run: 24, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   25   290.71          2.20362      332          2.01901              N/A      0.00s
# GP MAE: 1.5248, Run: 25, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   26   295.67          2.17186      406          2.01703              N/A      0.00s
# GP MAE: 1.5179, Run: 26, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   27   310.92          2.21081      406          2.01577              N/A      0.00s
# GP MAE: 1.5156, Run: 27, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   28   318.87           2.2232      340           2.0081              N/A      0.00s
# GP MAE: 1.5200, Run: 28, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   29   322.81          2.21337      672          2.00763              N/A      0.00s
# GP MAE: 1.5145, Run: 29, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   30   318.02          2.18921      383          2.00617              N/A      0.00s
# GP MAE: 1.5199, Run: 30, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   31   334.06          2.17418      401          2.00439              N/A      0.00s
# GP MAE: 1.5257, Run: 31, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   32   329.60          2.17676      397          2.00247              N/A      0.00s
# GP MAE: 1.5178, Run: 32, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   33   332.04          2.16109      443          2.00122              N/A      0.00s
# GP MAE: 1.5255, Run: 33, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   34   337.83          2.20361      327          1.99329              N/A      0.00s
# GP MAE: 1.5636, Run: 34, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   35   330.90          2.13456      320          1.99221              N/A      0.00s
# GP MAE: 1.5626, Run: 35, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   36   338.41           2.2028      337             1.99              N/A      0.00s
# GP MAE: 1.5644, Run: 36, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   37   318.00          2.15599      316          1.98751              N/A      0.00s
# GP MAE: 1.5533, Run: 37, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   38   309.84          2.24819      275          1.98663              N/A      0.00s
# GP MAE: 1.5578, Run: 38, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   39   304.14           2.1742      324          1.98339              N/A      0.00s
# GP MAE: 1.5449, Run: 39, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   40   300.78          2.18187      484          1.98262              N/A      0.00s
# GP MAE: 1.5567, Run: 40, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   41   313.54          2.15415      491          1.98069              N/A      0.00s
# GP MAE: 1.5539, Run: 41, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   42   323.64          2.13569      590          1.97966              N/A      0.00s
# GP MAE: 1.5532, Run: 42, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   43   334.71          2.12455      516          1.97848              N/A      0.00s
# GP MAE: 1.5536, Run: 43, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   44   320.81          2.12355      273          1.97769              N/A      0.00s
# GP MAE: 1.5573, Run: 44, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   45   309.96          2.13938      353          1.97597              N/A      0.00s
# GP MAE: 1.5650, Run: 45, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   46   301.29          2.20981      276          1.97531              N/A      0.00s
# GP MAE: 1.5507, Run: 46, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   47   289.57          2.16982      287           1.9725              N/A      0.00s
# GP MAE: 1.5393, Run: 47, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   48   273.21          2.18397      230          1.97126              N/A      0.00s
# GP MAE: 1.5589, Run: 48, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   49   261.64          2.18927      214          1.96979              N/A      0.00s
# GP MAE: 1.5614, Run: 49, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   50   258.18          2.16866      259          1.96797              N/A      0.00s
# GP MAE: 1.5613, Run: 50, Best Run: 15, Fold: 1
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   51   251.87          2.15225      333          1.96764              N/A      0.00s
# ...
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   33   157.96          2.24824      163          2.01104              N/A      0.00s
# GP MAE: 1.5335, Run: 33, Best Run: 32, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   34   159.22          2.23033      162          2.01025              N/A      0.00s
# GP MAE: 1.5338, Run: 34, Best Run: 32, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   35   155.41          2.21531      165          2.00674              N/A      0.00s
# GP MAE: 1.5311, Run: 35, Best Run: 35, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   36   159.48           2.2157      157          2.00625              N/A      0.00s
# GP MAE: 1.5309, Run: 36, Best Run: 36, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   37   162.79          2.23051      167          2.00589              N/A      0.00s
# GP MAE: 1.5306, Run: 37, Best Run: 37, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   38   166.48          2.20904      193           2.0048              N/A      0.00s
# GP MAE: 1.5286, Run: 38, Best Run: 38, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   39   155.75          2.19028      169          2.00361              N/A      0.00s
# GP MAE: 1.5275, Run: 39, Best Run: 39, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   40   157.56          2.22376      191          2.00329              N/A      0.00s
# GP MAE: 1.5280, Run: 40, Best Run: 39, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   41   163.03          2.21588      176          2.00228              N/A      0.00s
# GP MAE: 1.5265, Run: 41, Best Run: 41, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   42   163.40          2.18788      158          1.99996              N/A      0.00s
# GP MAE: 1.5249, Run: 42, Best Run: 42, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   43   171.90          2.19467      161           1.9982              N/A      0.00s
# GP MAE: 1.5248, Run: 43, Best Run: 43, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   44   174.53          2.20726      230          1.99747              N/A      0.00s
# GP MAE: 1.5249, Run: 44, Best Run: 43, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   45   174.17          2.19846      267          1.99551              N/A      0.00s
# GP MAE: 1.5227, Run: 45, Best Run: 45, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   46   190.89          2.16814      231          1.99343              N/A      0.00s
# GP MAE: 1.5248, Run: 46, Best Run: 45, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   47   207.76          2.18686      225          1.99254              N/A      0.00s
# GP MAE: 1.5272, Run: 47, Best Run: 45, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   48   199.58          2.20014      190          1.99167              N/A      0.00s
# GP MAE: 1.5235, Run: 48, Best Run: 45, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   49   215.19          2.16665      401          1.99098              N/A      0.00s
# GP MAE: 1.5246, Run: 49, Best Run: 45, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   50   208.28          2.16324      132          1.98864              N/A      0.00s
# GP MAE: 1.5221, Run: 50, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   51   196.53          2.17881      230          1.98533              N/A      0.00s
# GP MAE: 1.5238, Run: 51, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   52   195.26          2.17359      198          1.98258              N/A      0.00s
# GP MAE: 1.5221, Run: 52, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   53   191.66           2.1785      198          1.98137              N/A      0.00s
# GP MAE: 1.5229, Run: 53, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   54   204.84          2.15289      274          1.98058              N/A      0.00s
# GP MAE: 1.5246, Run: 54, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   55   207.68          2.15434      339          1.97783              N/A      0.00s
# GP MAE: 1.5257, Run: 55, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   56   199.83          2.15668      339          1.97445              N/A      0.00s
# GP MAE: 1.5237, Run: 56, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   57   201.18          2.15842      337           1.9739              N/A      0.00s
# GP MAE: 1.5234, Run: 57, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   58   237.74          2.15165      397           1.9724              N/A      0.00s
# GP MAE: 1.5225, Run: 58, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   59   283.56          2.18717      177          1.96923              N/A      0.00s
# GP MAE: 1.5263, Run: 59, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   60   236.92          2.15192      300          1.96836              N/A      0.00s
# GP MAE: 1.5265, Run: 60, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   61   204.26          2.19731      174          1.96735              N/A      0.00s
# GP MAE: 1.5267, Run: 61, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   62   193.15          2.18123      189           1.9659              N/A      0.00s
# GP MAE: 1.5295, Run: 62, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   63   178.21          2.16205      169          1.96446              N/A      0.00s
# GP MAE: 1.5271, Run: 63, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   64   173.94          2.19279      173           1.9623              N/A      0.00s
# GP MAE: 1.5260, Run: 64, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   65   181.38           2.1806      323          1.96068              N/A      0.00s
# GP MAE: 1.5233, Run: 65, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   66   188.63          2.18069      325          1.96009              N/A      0.00s
# GP MAE: 1.5237, Run: 66, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   67   197.40          2.22172      412          1.95918              N/A      0.00s
# GP MAE: 1.5221, Run: 67, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   68   204.75          2.16548      251          1.95868              N/A      0.00s
# GP MAE: 1.5243, Run: 68, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   69   195.78            2.165      255          1.95805              N/A      0.00s
# GP MAE: 1.5251, Run: 69, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   70   195.28          2.19203      294          1.95733              N/A      0.00s
# GP MAE: 1.5231, Run: 70, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   71   204.41          2.15054      188          1.95706              N/A      0.00s
# GP MAE: 1.5247, Run: 71, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   72   217.46          2.14619      312          1.95663              N/A      0.00s
# GP MAE: 1.5232, Run: 72, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   73   230.18           2.1315      210          1.95547              N/A      0.00s
# GP MAE: 1.5260, Run: 73, Best Run: 50, Fold: 4
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#   74   233.81          2.14027      210          1.95547              N/A      0.00s
# GP MAE: 1.5260, Run: 74, Best Run: 50, Fold: 4
# Finish - GP MAE: 1.5260, Run: 74, Best Run: 50
# [3.30678138 5.61812196 4.73183529 8.31575305 6.61428548 2.56558642
#  7.18472713 4.52727687 4.62369708 1.91770885 3.01145713 5.06784202]
# [1.4474297120148814, 1.490953474890839, 1.5539456660585609, 1.1987791732217843, 1.522094645661991]
# 1.4426405343696114
# [74, 66, 74, 74, 74]

# %%
#Code above with kfolds gets better result Than this simple one
"""
est_gp.fit(X_train_scaled , y_train.values.flatten())

y_gp = est_gp.predict(X_train_scaled)
gpLearn_MAE = mean_absolute_error(y_tr.values.flatten(), y_gp)
print("gpGpiLearn MAE:", gpLearn_MAE)
"""
# Out:
# '\nest_gp.fit(X_train_scaled , y_train.values.flatten())\n\ny_gp = est_gp.predict(X_train_scaled)\ngpLearn_MAE = mean_absolute_error(y_tr.values.flatten(), y_gp)\nprint("gpGpiLearn MAE:", gpLearn_MAE)\n'

# %%
"""

# This can be used to create a download link for the submission file

from IPython.display import HTML
import base64

def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(submission)
"""
# Out:
# '\n\n# This can be used to create a download link for the submission file\n\nfrom IPython.display import HTML\nimport base64\n\ndef create_download_link(df, title = "Download CSV file", filename = "data.csv"):  \n    csv = df.to_csv()\n    b64 = base64.b64encode(csv.encode())\n    payload = b64.decode()\n    html = \'<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>\'\n    html = html.format(payload=payload,title=title,filename=filename)\n    return HTML(html)\n\ncreate_download_link(submission)\n'
